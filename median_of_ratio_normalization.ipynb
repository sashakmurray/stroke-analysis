# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#unfiltered gene counts table
raw_counts = pd.read_csv('Unfiltered Gene Counts Table Joined.tsv', sep='\t')
raw_counts.head()
# Out:
#            Gene_ID  Ctrl_F1  Ctrl_F2  AIS_M1  Ctrl_M1  AIS_M2  Ctrl_M2  \
# 0  ENSG00000082929    139.0    110.0     7.0    219.0    28.0     60.0
# 1  ENSG00000115934      1.0      1.0     3.0      2.0     6.0      1.0
# 2  ENSG00000122043      8.0     11.0    10.0    971.0    47.0     13.0
# 3  ENSG00000122548    421.0      4.0   187.0     16.0   561.0      1.0
# 4  ENSG00000124915      4.0     24.0   206.0   1010.0   403.0    138.0
#
#    Ctrl_M3  AIS_M3  AIS_M4  ...  Ctrl_M5  AIS_F1  Ctrl_F5  Ctrl_F6  AIS_F2  \
# 0     12.0   251.0     4.0  ...     70.0    13.0     33.0     14.0   503.0
# 1      3.0   178.0     3.0  ...      0.0    10.0     11.0      9.0   464.0
# 2     19.0    21.0   172.0  ...     59.0   266.0     57.0     22.0    32.0
# 3    227.0   186.0     3.0  ...     19.0    15.0      8.0      8.0    14.0
# 4      7.0    21.0   187.0  ...     54.0    23.0   1012.0    675.0    14.0
#
#    AIS_F3  AIS_F4  AIS_F5  AIS_F6  Ctrl_F7
# 0   179.0    22.0   153.0   123.0      5.0
# 1     5.0     2.0     2.0   218.0      0.0
# 2    10.0   421.0   510.0   255.0     12.0
# 3   215.0    34.0   167.0     0.0    263.0
# 4    10.0   319.0   395.0    88.0      4.0
#
# [5 rows x 29 columns]

# %%
#set gene id as index and drop genes with zero count (for calculating geometric mean)
counts = raw_counts.loc[~(raw_counts == 0).any(axis=1)].iloc[:-1].set_index('Gene_ID')
counts.head()
# Out:
#                  Ctrl_F1  Ctrl_F2  AIS_M1  Ctrl_M1  AIS_M2  Ctrl_M2  Ctrl_M3  \
# Gene_ID
# ENSG00000082929    139.0    110.0     7.0    219.0    28.0     60.0     12.0
# ENSG00000122043      8.0     11.0    10.0    971.0    47.0     13.0     19.0
# ENSG00000124915      4.0     24.0   206.0   1010.0   403.0    138.0      7.0
# ENSG00000125514    270.0    289.0   399.0    368.0   468.0    272.0    491.0
# ENSG00000125804     10.0    250.0   206.0    886.0    32.0    613.0   1548.5
#
#                  AIS_M3  AIS_M4  AIS_M5  ...  Ctrl_M5  AIS_F1  Ctrl_F5  \
# Gene_ID                                  ...
# ENSG00000082929   251.0     4.0   284.0  ...     70.0    13.0     33.0
# ENSG00000122043    21.0   172.0   273.0  ...     59.0   266.0     57.0
# ENSG00000124915    21.0   187.0    13.0  ...     54.0    23.0   1012.0
# ENSG00000125514   707.0    88.0   669.0  ...    126.0   594.0    383.0
# ENSG00000125804    25.0    37.0   832.0  ...     87.0  1360.0   1756.0
#
#                  Ctrl_F6  AIS_F2  AIS_F3  AIS_F4  AIS_F5  AIS_F6  Ctrl_F7
# Gene_ID
# ENSG00000082929     14.0   503.0   179.0    22.0   153.0   123.0      5.0
# ENSG00000122043     22.0    32.0    10.0   421.0   510.0   255.0     12.0
# ENSG00000124915    675.0    14.0    10.0   319.0   395.0    88.0      4.0
# ENSG00000125514    557.0   662.0   320.0    68.0    18.0   482.0    178.0
# ENSG00000125804    764.0   588.0   241.0  1074.0   268.0   139.0    131.0
#
# [5 rows x 28 columns]

# %%
#add pseudo reference sample (row wise geometric mean)
counts['pseudo_reference_sample'] = counts.apply(lambda x: np.exp(np.log(x).mean()), axis=1)
counts.head()
# Out:
#                  Ctrl_F1  Ctrl_F2  AIS_M1  Ctrl_M1  AIS_M2  Ctrl_M2  Ctrl_M3  \
# Gene_ID
# ENSG00000082929    139.0    110.0     7.0    219.0    28.0     60.0     12.0
# ENSG00000122043      8.0     11.0    10.0    971.0    47.0     13.0     19.0
# ENSG00000124915      4.0     24.0   206.0   1010.0   403.0    138.0      7.0
# ENSG00000125514    270.0    289.0   399.0    368.0   468.0    272.0    491.0
# ENSG00000125804     10.0    250.0   206.0    886.0    32.0    613.0   1548.5
#
#                  AIS_M3  AIS_M4  AIS_M5  ...  AIS_F1  Ctrl_F5  Ctrl_F6  \
# Gene_ID                                  ...
# ENSG00000082929   251.0     4.0   284.0  ...    13.0     33.0     14.0
# ENSG00000122043    21.0   172.0   273.0  ...   266.0     57.0     22.0
# ENSG00000124915    21.0   187.0    13.0  ...    23.0   1012.0    675.0
# ENSG00000125514   707.0    88.0   669.0  ...   594.0    383.0    557.0
# ENSG00000125804    25.0    37.0   832.0  ...  1360.0   1756.0    764.0
#
#                  AIS_F2  AIS_F3  AIS_F4  AIS_F5  AIS_F6  Ctrl_F7  \
# Gene_ID
# ENSG00000082929   503.0   179.0    22.0   153.0   123.0      5.0
# ENSG00000122043    32.0    10.0   421.0   510.0   255.0     12.0
# ENSG00000124915    14.0    10.0   319.0   395.0    88.0      4.0
# ENSG00000125514   662.0   320.0    68.0    18.0   482.0    178.0
# ENSG00000125804   588.0   241.0  1074.0   268.0   139.0    131.0
#
#                  pseudo_reference_sample
# Gene_ID
# ENSG00000082929                75.445251
# ENSG00000122043                63.951647
# ENSG00000124915               105.044315
# ENSG00000125514               208.742470
# ENSG00000125804               279.798042
#
# [5 rows x 29 columns]

# %%
#calulate ratio of each sample to reference
ratios = counts.div(counts['pseudo_reference_sample'], axis=0).iloc[:, :-1]
ratios.head()
# Out:
#                   Ctrl_F1   Ctrl_F2    AIS_M1    Ctrl_M1    AIS_M2   Ctrl_M2  \
# Gene_ID
# ENSG00000082929  1.842396  1.458011  0.092783   2.902767  0.371130  0.795279
# ENSG00000122043  0.125095  0.172005  0.156368  15.183346  0.734930  0.203279
# ENSG00000124915  0.038079  0.228475  1.961077   9.614990  3.836476  1.313731
# ENSG00000125514  1.293460  1.384481  1.911446   1.762938  2.241997  1.303041
# ENSG00000125804  0.035740  0.893502  0.736245   3.166570  0.114368  2.190866
#
#                   Ctrl_M3    AIS_M3    AIS_M4    AIS_M5  ...   Ctrl_M5  \
# Gene_ID                                                  ...
# ENSG00000082929  0.159056  3.326916  0.053019  3.764319  ...  0.927825
# ENSG00000122043  0.297099  0.328373  2.689532  4.268850  ...  0.922572
# ENSG00000124915  0.066639  0.199916  1.780201  0.123757  ...  0.514069
# ENSG00000125514  2.352181  3.386949  0.421572  3.204906  ...  0.603615
# ENSG00000125804  5.534349  0.089350  0.132238  2.973573  ...  0.310939
#
#                    AIS_F1   Ctrl_F5   Ctrl_F6    AIS_F2    AIS_F3    AIS_F4  \
# Gene_ID
# ENSG00000082929  0.172310  0.437403  0.185565  6.667086  2.372581  0.291602
# ENSG00000122043  4.159392  0.891298  0.344010  0.500378  0.156368  6.583099
# ENSG00000124915  0.218955  9.634029  6.425859  0.133277  0.095198  3.036814
# ENSG00000125514  2.845612  1.834797  2.668360  3.171372  1.532989  0.325760
# ENSG00000125804  4.860649  6.275955  2.730541  2.101516  0.861336  3.838483
#
#                    AIS_F5    AIS_F6   Ctrl_F7
# Gene_ID
# ENSG00000082929  2.027961  1.630321  0.066273
# ENSG00000122043  7.974775  3.987388  0.187642
# ENSG00000124915  3.760318  0.837742  0.038079
# ENSG00000125514  0.086231  2.309065  0.852725
# ENSG00000125804  0.957834  0.496787  0.468195
#
# [5 rows x 28 columns]

# %%
#find the median of ratio for each sample to use as normalization factor
medians = ratios.median(axis=0)
medians
# Out:
# Ctrl_F1    0.645953
# Ctrl_F2    0.807942
# AIS_M1     0.784621
# Ctrl_M1    1.812835
# AIS_M2     1.600587
# Ctrl_M2    0.786983
# Ctrl_M3    1.315733
# AIS_M3     1.413179
# AIS_M4     0.851589
# AIS_M5     1.332906
# AIS_M6     0.642996
# Ctrl_M4    1.178797
# AIS_M7     0.796924
# Ctrl_F3    2.369873
# AIS_M8     1.197753
# AIS_M9     1.499815
# Ctrl_F4    1.709899
# AIS_M10    1.270794
# Ctrl_M5    0.399699
# AIS_F1     1.609493
# Ctrl_F5    1.859238
# Ctrl_F6    1.299120
# AIS_F2     1.258875
# AIS_F3     0.813604
# AIS_F4     1.278082
# AIS_F5     2.252808
# AIS_F6     0.824923
# Ctrl_F7    0.511354
# dtype: float64

# %%
#divide counts by normalization factor
normalized_counts = counts.div(medians, axis=1)
normalized_counts.head()
# Out:
#                      AIS_F1      AIS_F2      AIS_F3      AIS_F4      AIS_F5  \
# Gene_ID
# ENSG00000082929    8.077076  399.562944  220.008617   17.213296   67.915247
# ENSG00000122043  165.269401   25.419511   12.290984  329.399892  226.384158
# ENSG00000124915   14.290211   11.121036   12.290984  249.592792  175.336750
# ENSG00000125514  369.060241  525.866141  393.311494   53.204733    7.990029
# ENSG00000125804  844.986411  467.083521  296.212719  840.321814  118.962656
#
#                      AIS_F6      AIS_M1     AIS_M10      AIS_M2      AIS_M3  \
# Gene_ID
# ENSG00000082929  149.104875    8.921504  485.523159   17.493582  177.613778
# ENSG00000122043  309.119864   12.745006   17.312009   29.364227   14.860117
# ENSG00000124915  106.676659  262.547121  297.451789  251.782626   14.860117
# ENSG00000125514  584.297154  508.525734   11.803642  292.392726  500.290600
# ENSG00000125804  168.500632  262.547121  166.824813   19.992665   17.690615
#
#                  ...     Ctrl_F4     Ctrl_F5     Ctrl_F6     Ctrl_F7  \
# Gene_ID          ...
# ENSG00000082929  ...   14.620747   17.749208   10.776524    9.777955
# ENSG00000122043  ...  394.760176   30.657723   16.934537   23.467093
# ENSG00000124915  ...  175.448967  544.309054  519.582396    7.822364
# ENSG00000125514  ...  230.422977  205.998387  428.751696  348.095209
# ENSG00000125804  ...  390.666367  944.473023  588.090297  256.182429
#
#                     Ctrl_M1     Ctrl_M2      Ctrl_M3      Ctrl_M4     Ctrl_M5  \
# Gene_ID
# ENSG00000082929  120.805253   76.240528     9.120391   278.249797  175.131985
# ENSG00000122043  535.625118   16.518781    14.440619    13.573161  147.611244
# ENSG00000124915  557.138382  175.353213     5.320228   504.751919  135.101817
# ENSG00000125514  202.996955  345.623725   373.176007   166.271220  315.237572
# ENSG00000125804  488.737234  778.924056  1176.910483  1236.005958  217.664038
#
#                  pseudo_reference_sample
# Gene_ID
# ENSG00000082929                      NaN
# ENSG00000122043                      NaN
# ENSG00000124915                      NaN
# ENSG00000125514                      NaN
# ENSG00000125804                      NaN
#
# [5 rows x 29 columns]
